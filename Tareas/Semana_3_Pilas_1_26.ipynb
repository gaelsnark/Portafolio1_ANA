# %% [markdown]
# # Semana 3: Pilas

# %% [markdown]
# Para esta asignación se recomienda que utilices la siguiente implemetnación para el arreglo pilas.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []  # nonpublic list instance

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)  # new item stored at end of list

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data.pop()  # remove last

# %% [markdown]
# **R-6.1**
#  What values are returned during the following series of stack operations, if
#  executed upon an initially empty stack? push(5), push(3), pop(), push(2),
#  push(8), pop(), pop(), push(9), push(1), pop(), push(7), push(6), pop(),
#  pop(), push(4), pop(), pop().

# %% [markdown]
# | Operation step | Stack operation | Value returned (if any) | Stack state after operation |
# | -------------- | --------------- | ----------------------- | --------------------------- |
# | 1              | push(5)         |           -              |     5         |
# | 2              | push(3)         |           -              |       5,3       |
# | 3              | pop()           |            3             |         5     |
# | 4              | push(2)         |            -             |        5,2      |
# | 5              | push(8)         |             -            |      5,2,8        |
# | 6              | pop()           |             8            |       5,2       |
# | 7              | pop()           |               2          |          5    |
# | 8              | push(9)         |            -             |        5,9      |
# | 9              | push(1)         |           -              |      5,9,1        |
# | 10             | pop()           |            1             |     5,9         |
# | 11             | push(7)         |            -             |      5,9,7        |
# | 12             | push(6)         |             -            |        5,9,7,6      |
# | 13             | pop()           |            6            |      5,9,7       |
# | 14             | pop()           |             7            |       5,9       |
# | 15             | push(4)         |              -           |        5,9,4      |
# | 16             | pop()           |               4          |        5,9      |
# | 17             | pop()           |               9          |       5       |

# %% [markdown]
# **R-6.2** Suppose an initially empty stack $S$ has executed a total of 25 push operations, 12 top operations, and 10 pop operations, 3 of which raised Empty errors that were caught and ignored. What is the current size of $S$?

# %% [markdown]
# ### Respuesta
# El push hace que cada que agregues un elemento nuevo con push(n), ese elemento se coloque al final de la lista y así sucesivamente, pero no retorna un valor, solo lo va guardando.
# El pop(), elimina ese nuevo elemento de la lista y muestra el valor que se elimina se muestra al usuario.
# Primero que entra primero que sale
# Primero S contiene 25 push, o sea 25 stack en la lista, luego te dice que 12 top operations solo para mostrar los últimos 12 valores.
# Con esto, hacemos 10 pop y tres de esos pop dan error.
#
# $ S = 18 $

# %% [markdown]
# **R-6.3** Implement a function with signature transfer(S, T) that transfers all elements from stack $S$ onto stack $T$, so that the element that starts at the top of $S$ is the first to be inserted onto $T$, and the element at the bottom of $S$ ends up at the top of $T$.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []  # nonpublic list instance

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)  # new item stored at end of list

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data.pop()  # remove last
    
    
    def showstack(self):
        if self.is_empty():
            raise Empty("La lista está vacía")
        print(self._data)
        
    

def transfer(S,T):
    if S != None:
        T.push(S.pop())
    return T

# %%
d=ArrayStack()

d.push(1)
d.push(2)

t=ArrayStack()

transfer(d,t)
t.showstack()
# Out:
# [2, 1]

# %% [markdown]
# **R-6.4** Give a recursive method for removing all the elements from a stack.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self):
        """Create an empty stack."""
        self._data = []  # nonpublic list instance

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self, e):
        """Add element e to the top of the stack."""
        self._data.append(e)  # new item stored at end of list
    
    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list
    
    def rango(self):
        inicio = 0
        final = int(input("Rango final permitido: "))
        return inicio, final

    def askitem(self):
        inicio, final = self.rango()

        while len(self._data) < final:
            usage = int(input("Qué valor quiere agregar: "))
            if usage in range(inicio, final + 1):
                self.push(usage)
            else:
                print(f"El valor debe estar entre {inicio} y {final}")

        print("Lista completa:", self._data)

        
   
    """def __iter__(self):
        it=0
        while True:
            try:
                yield value # Yield es una función que devuelve valores 1 por 1 pausándose entre cada uno en lugar de devolver todos de una sola vez
                value=self._data.__getitem__(it)
                it+=1
            except IndexError:
                break"""
        
    def __getitem__(self,index):
        return self._data[-1-index]

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data.pop()  # remove last
    
    def showstack(self):
        if len(self._data) == 0:
            raise Empty("La lista está vacía")
        
        print(self._data)
    
    def remove(self):
        ask = str(input("Desear vaciar toda la lista: "))
       
        if ask != 'si':
            return self
            
        while not self.is_empty():
            self.pop()
            
        print("Lista vacía")
        return self

# %%
inst1=ArrayStack()

inst1.rango()
inst1.askitem()
inst1.showstack()
inst1.remove()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 4
#       1 inst1=ArrayStack()
#       2
#       3 inst1.rango()
# ----> 4 inst1.askitem()
#       5 inst1.showstack()
#       6 inst1.remove()
#
# Cell In[84], line 38, in ArrayStack.askitem(self)
#      37     def askitem(self):
# ---> 38         inicio, final = self.rango()
#      39
#      40         while len(self._data) < final:
#      41             usage = int(input("Qué valor quiere agregar: "))
#
# Cell In[84], line 34, in ArrayStack.rango(self)
#      32     def rango(self):
#      33         inicio = 0
# ---> 34         final = int(input("Rango final permitido: "))
#      35         return final
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# **R-6.5** Implement a function that reverses a list of elements by pushing them onto a stack in one order, and writing them back to the list in reversed order.

# %%
def __getitem__(self,index):
        while not self._data.is_empty():
            return self._data[-1-index] # 0-1=[-1], -1-1=[-2] regresa los últimos valores

# %% [markdown]
# **C-6.16** Modify the ArrayStack implementation so that the stack’s capacity is limited to maxlen elements, where maxlen is an optional parameter to the constructor (that defaults to None). If push is called when the stack is at full capacity, throw a Full exception (defined similarly to Empty).

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class Full(Exception):
    """Error attempting to push into a full stack."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self,maxlen = None):
        """Create an empty stack."""
        self._data = []  # nonpublic list instance
        self._maxlen = maxlen

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self,e):
        if self._maxlen is not None and len(self._data) == self._maxlen:
            raise Full('Stack is full')
        self._data.append(e)

    def showstack(self):
        if len(self._data) == 0:
            raise Empty("La lista está vacía")
        
        if self._maxlen is not None and len(self._data) == self._maxlen:
            raise Full('Stack is full')
        print(self._data)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list

    def pop(self):
        """Remove and return the element from the top of the stack (i.e., LIFO).
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data.pop()  # remove last

# %%
inst= ArrayStack()
inst.push(30)
inst.push(50)
inst.push(80)
inst.showstack()
# Out:
# [30, 50, 80]

# %% [markdown]
# **C-6.17** In the previous exercise, we assume that the underlying list is initially empty. Redo that exercise, this time preallocating an underlying list with length equal to the stack’s maximum capacity.

# %%
class Empty(Exception):
    """Error attempting to access an element from an empty container."""
    pass

class Full(Exception):
    """Error attempting to push into a full stack."""
    pass

class ArrayStack:
    """LIFO Stack implementation using a Python list as underlying storage."""

    def __init__(self,maxlen = None):
        """Create an empty stack."""
        self._num= 0   # cantidad real de elementos usados
        self._maxlen = maxlen
        if maxlen is not None:
            self._data = [None] * maxlen  # lista preasignada
        else:
            self._data = []

    def __len__(self):
        """Return the number of elements in the stack."""
        return len(self._data)

    def is_empty(self):
        """Return True if the stack is empty."""
        return len(self._data) == 0

    def push(self,e):
        if self._maxlen is not None:
            if self._n == self._maxlen:
                raise Full('Stack is full')
            self._data[self._n] = e  # se escribe usando la posición reservada 
        else:
            self._data.append(e)
        self._n += 1

    def showstack(self):
        if len(self._data) == 0:
            raise Empty("La lista está vacía")
        
        if self._maxlen is not None and len(self._data) == self._maxlen:
            raise Full('Stack is full')
        print(self._data)

    def top(self):
        """Return (but do not remove) the element at the top of the stack.
        Raise Empty exception if the stack is empty.
        """
        if self.is_empty():
            raise Empty('Stack is empty')
        return self._data[-1]  # the last item in the list

    def pop(self):
        if self.is_empty():
            raise Empty('Stack is empty')
        self._n -= 1
        val = self._data[self._n]
        if self._maxlen is not None:
            self._data[self._n] = None 
        else:
            self._data.pop()
        return val
