# %% [markdown]
# ###Esto es una celda para texto
#
# Todo el texto que se escriba en esta celda será ignorado por el intérprete
#
#
# * Las celdas de markdown nos permiten visualizar fórmulas matemáticas escritas con código latex
# $ f(x) = x^2

# %%
print("Hola mundo")
# Out:
# Hola mundo
